# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib notebook
import numpy as np
import arrayfire as af
import scipy.io as sio
import scipy.linalg as la
import matplotlib.pyplot as plt
import os
import sys
import fnmatch
np.set_printoptions(threshold=np.nan)
import contexttimer
#For Lahvahn
sys.path.append('D:\\David\\libwallerlab\\python\\libwallerlab\\tomography_gpu')
#For YONGHUAN_PC
sys.path.append('L:\\David\\libwallerlab\\python\\libwallerlab\\tomography_gpu')
#For COSMOS
sys.path.append('/home/david/lahvahn_david/libwallerlab/python/libwallerlab/tomography_gpu/')
#For others
sys.path.append('T:\\David\\libwallerlab\\python\\libwallerlab\\tomography_gpu')
from opticaltomography.opticsutil import compare3DStack

# %% [markdown]
# ### Specify file path

# %%
# Specify datapath
data_path  = "%s/%s"   % (os.getcwd(), "../data/")
indir      = "%s%s" % (data_path, "reconstruction/")
outdir     = "%s%s" % (data_path, "atomtrace/")
print("hostname:", os.uname()[1])
import arrayfire as af
af.set_device(0)
# Out:
# hostname: waller-cosmos

# %% [markdown]
# ### Specify experiments to run

# %%
#Experiments to be run
exps = [5004]

# %% [markdown]
# ### Load Data

# %%
for exp_i in exps:
    for file in os.listdir(indir):
        if fnmatch.fnmatch(file, "exp%s*" % (str(exp_i))):
            print(file)
            reconstruction = sio.loadmat(indir+file, squeeze_me=True)
            obj_final = reconstruction["obj_final"].real
            break
# Out:
# exp5004_sim_sio2_full_FISTA_batch1_positivity_and_real_tv_gpu_random_order.mat

# %% [markdown]
# ### Prepare kernel

# %%
kernel_size = 11
coord = np.arange(-(kernel_size//2),kernel_size//2+1)
[zz, yy, xx] = np.meshgrid(coord, coord, coord)
s1=1
r2 = xx**2 + yy**2 + zz**2
kernel = -1*((r2 - 3*(s1**2))/np.sqrt(2*np.pi*(s1**2))) * np.exp(-r2/(2*(s1**2)))
plt.figure()
plt.imshow(kernel[kernel_size//2,])
plt.colorbar()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# ### Filter

# %%
obj_final = np.array(af.to_array(obj_final))
atoms = np.array(af.convolve3(af.to_array(obj_final), af.to_array(kernel))).real

# %% [markdown]
# ### Before and after filtering

# %%
min_val = np.min(obj_final[:])
max_val = np.max(obj_final[:])
print("min:", min_val)
print("max:", max_val)
min_val1 = np.min(atoms[:])
max_val1 = np.max(atoms[:])
print("min:", min_val1)
print("max:", max_val1)
# Out:
# min: 0.0
# max: 320.04617
# min: -100.909256
# max: 640.4917

# %%
plt.figure()
atoms[atoms < 300]=0
plt.hist(atoms.ravel(), bins = 100, range = [300, max_val1])
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# (array([3.454e+03, 3.238e+03, 3.039e+03, 2.857e+03, 2.793e+03, 2.565e+03,
#         2.334e+03, 2.236e+03, 2.158e+03, 2.143e+03, 2.060e+03, 1.960e+03,
#         1.835e+03, 1.901e+03, 1.710e+03, 1.713e+03, 1.651e+03, 1.689e+03,
#         1.583e+03, 1.502e+03, 1.475e+03, 1.439e+03, 1.410e+03, 1.394e+03,
#         1.288e+03, 1.282e+03, 1.297e+03, 1.221e+03, 1.243e+03, 1.264e+03,
#         1.199e+03, 1.123e+03, 1.173e+03, 1.136e+03, 1.086e+03, 1.077e+03,
#         1.070e+03, 1.118e+03, 1.047e+03, 9.850e+02, 9.980e+02, 9.650e+02,
#         8.930e+02, 8.770e+02, 8.610e+02, 8.280e+02, 8.720e+02, 8.320e+02,
#         7.980e+02, 6.930e+02, 6.650e+02, 6.650e+02, 6.450e+02, 5.940e+02,
#         5.400e+02, 5.300e+02, 5.050e+02, 5.080e+02, 4.300e+02, 4.400e+02,
#         4.060e+02, 3.710e+02, 3.250e+02, 2.850e+02, 2.680e+02, 2.780e+02,
#         2.390e+02, 1.970e+02, 1.830e+02, 1.760e+02, 1.640e+02, 1.360e+02,
# ...

# %%
compare3DStack(obj_final, atoms, clim=(min_val,max_val))
# Out:
# <img src="data:image/png;base64,..." width="999.9999783255842">
